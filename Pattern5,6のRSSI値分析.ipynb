# %% [markdown]
# ### 取得したデータからRSSIの値の変化を見る

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline
sns.set_style('whitegrid')
sns.set_context("poster")
sns.set_context("talk", 1.0, {"lines.linewidth": 3})

# %% [markdown]
# ### pattern5のデータを分析
# pattern5では受信機の向きを考慮した基礎実験を行なっている。
# ４隅に置いた発信機に対してBLE受信機のドングルの向きを変えてRSSI値の変化をみる。
# <img src="./RSSI取得実験図/pattern5.png" alt="パターン5">
# <img src="./RSSI取得実験図/pattern5-1.JPG" alt="パターン5-1">
# <img src="./RSSI取得実験図/pattern5-2.JPG" alt="パターン5-2">
# <img src="./RSSI取得実験図/pattern5-3.JPG" alt="パターン5-3">

# %%
# pattern5の各実験データをそれぞれ取得
P5_1 = pd.read_csv("./取得データセット/受信機1/nkmr1_pattern5.csv")
P5_2 = pd.read_csv("./取得データセット/受信機2/nkmr2_pattern5.csv")
P5_3 = pd.read_csv("./取得データセット/受信機3/nkmr3_pattern5.csv")

# それぞれカラム名を指定
P5_1.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
P5_2.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
P5_3.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]

# 結合
df5 = P5_1.append(P5_2).append(P5_3)

# %% [markdown]
# ### 1.全受信機の分布

# %%
# 受信した全てのデータの分布を見る
sns.distplot(pd.Series(df5["RSSI"],name = "全受信機の分布"))

# データ数、平均値、分散を出力
print("データ数:%s" % df5["RSSI"].count())
print("平均値:%s" % df5["RSSI"].mean())
print("分散:%s" % df5["RSSI"].std())
# Out:
# データ数:28426
# 平均値:-85.7927249700978
# 分散:3.936455399089386

# %% [markdown]
# パターン１(４隅に発信器を設置、受信機は１つ)の時よりも分散の値が１以上大きくなっている。
# 平均値はほぼ同様である。

# %% [markdown]
# ### 2.受信機ごとの分布
# 受信機ごとのRSSI値の分布を見ることでBLEドングルの向きによりどれくらいRSSIに変化があるのかを見る。

# %% [markdown]
# #### 2-1.受信機1の分布

# %%
# 受信機1の全データ分布
sns.distplot(P5_1["RSSI"])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_1["RSSI"].count())
print("平均値:%s" % P5_1["RSSI"].mean())
print("分散:%s" % P5_1["RSSI"].std())
# Out:
# データ数:10113
# 平均値:-84.74468505883516
# 分散:3.988372846290535

# %%
# 発信機1の分布
sns.distplot(P5_1[P5_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_1[P5_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_1[P5_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_1[P5_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:3514
# 平均値:-83.22652248150256
# 分散:3.3213714249590596

# %%
# 発信機2の分布
sns.distplot(P5_1[P5_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_1[P5_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_1[P5_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_1[P5_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2678
# 平均値:-83.45556385362211
# 分散:2.736205057513968

# %%
# 発信機3の分布
sns.distplot(P5_1[P5_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_1[P5_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_1[P5_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_1[P5_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:1657
# 平均値:-91.69221484610742
# 分散:1.4195472783787026

# %%
# 発信機4の分布
sns.distplot(P5_1[P5_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_1[P5_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_1[P5_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_1[P5_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2264
# 平均値:-83.5410777385159
# 分散:1.1340119517167202

# %% [markdown]
# #### 考察(受信機1のRSSI値の分布)
# 平均:①-83.22652248150256、②-83.45556385362211、③-91.69221484610742、④-83.5410777385159
# 分散:①3.3213714249590596、②2.736205057513968、③1.4195472783787026、④1.1340119517167202
#
# 発信機ごとに平均値と分散値に違いが現れているのが見て取れる。
#
# 平均値 :
# ③の地点のRSSI平均値が顕著に小さい値を示していることがわかる。
# ③地点はBLEドングルが向いている方向と逆方向の地点である。
# その他の地点はRSSI値の平均がほぼ同じと言って良い。
#
# 分散値 :
# ①>②>③>④の順に半時計回りに分散の値が低い値をとっている。
#
#
# <img src="./RSSI取得実験図/pattern5-1.png" alt="パターン5">

# %% [markdown]
# #### 2-2.受信機2の分布

# %%
# 受信機2の全データ分布
sns.distplot(P5_2["RSSI"])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_2["RSSI"].count())
print("平均値:%s" % P5_2["RSSI"].mean())
print("分散:%s" % P5_2["RSSI"].std())
# Out:
# データ数:8495
# 平均値:-85.06180105944674
# 分散:4.379143292789627

# %%
# 発信機1の分布
sns.distplot(P5_2[P5_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_2[P5_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_2[P5_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_2[P5_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2998
# 平均値:-86.369913275517
# 分散:3.3663413839752447

# %%
# 発信機2の分布
sns.distplot(P5_2[P5_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_2[P5_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_2[P5_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_2[P5_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:579
# 平均値:-91.05354058721935
# 分散:1.0165926548745892

# %%
# 発信機3の分布
sns.distplot(P5_2[P5_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_2[P5_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_2[P5_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_2[P5_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:1304
# 平均値:-86.24539877300613
# 分散:2.2634389975554043

# %%
# 発信機4の分布
sns.distplot(P5_2[P5_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_2[P5_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_2[P5_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_2[P5_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:3614
# 平均値:-82.58965135583841
# 分散:4.45857561044336

# %% [markdown]
# #### 考察(受信機2のRSSI値の分布)
# 平均:①-86.369913275517、②-91.05354058721935、③-86.24539877300613、④-82.58965135583841
# 分散:①3.3663413839752447、②1.0165926548745892、③2.2634389975554043、④4.45857561044336
#
# 発信機ごとに平均値と分散値に違いが現れているのが見て取れる。
#
# 平均値 :
# BLEドングルと逆方向にある地点②はRSSIの平均値が低い値を取っている。
# BLEドングルが向いている方向である地点④ではRSSIの値が高い値を取っている。
# その他の地点ではほぼ同じ値である。
#
# 分散値 :
# 分散値は地点によってバラバラの値を取っている。理由がわからない。
#
# <img src="./RSSI取得実験図/pattern5-2.png" alt="パターン5">

# %% [markdown]
# #### 2-3.受信機3の分布

# %%
# 受信機3の全データ分布
sns.distplot(P5_3["RSSI"])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_3["RSSI"].count())
print("平均値:%s" % P5_3["RSSI"].mean())
print("分散:%s" % P5_3["RSSI"].std())
# Out:
# データ数:9818
# 平均値:-87.50468527194948
# 分散:2.7138548406102703

# %%
# 発信機1の分布
sns.distplot(P5_3[P5_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_3[P5_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_3[P5_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_3[P5_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2370
# 平均値:-88.6535864978903
# 分散:2.279406078432682

# %%
# 発信機2の分布
sns.distplot(P5_3[P5_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_3[P5_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_3[P5_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_3[P5_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:1505
# 平均値:-88.56677740863788
# 分散:3.421764163942052

# %%
# 発信機3の分布
sns.distplot(P5_3[P5_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_3[P5_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_3[P5_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_3[P5_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2468
# 平均値:-87.72325769854133
# 分散:1.8247038071501072

# %%
# 発信機4の分布
sns.distplot(P5_3[P5_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P5_3[P5_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P5_3[P5_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P5_3[P5_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:3475
# 平均値:-86.10589928057554
# 分散:2.540802838271228

# %% [markdown]
# #### 考察(受信機3のRSSI値の分布)
# 平均:①-88.6535864978903、②-88.56677740863788、③-87.72325769854133、④-86.10589928057554
# 分散:①2.279406078432682、②3.421764163942052、③1.8247038071501072、④2.540802838271228
#
# 平均値 :
# 平均値の値は地点によるばらつきは少ないことが見て取れる。
#
# 分散値 :
# BLEドングルが向いている方向である地点③の分散が低い値を示している。
# 他の地点は地点③よりも分散地が比較的に大きい。
#
# <img src="./RSSI取得実験図/pattern5-3.png" alt="パターン5">

# %% [markdown]
# ### pattern6のデータを分析
# pattern6では受信機の位置によってRSSI値にどのような変化があるのかを検証する。
# １m間隔に設置した発信機に対して３箇所に受信機を設置した。
#
# 前提知識：
# 電波の強さは距離の２乗に反比例して弱くなる。（フリスの伝達公式）
# RSSIとTxPowerとdの関係式は以下のようになる。
# (RSSIは電波強度、TxPowerは１メートル離れた場所で測定した電波の強さ、dは距離)
# RSSI = TxPower - 20 * log(d)
# 距離dの計算式は以下。
# d = 10 ^ ((TxPower - RSSI) / 20)
#
# <img src="./RSSI取得実験図/pattern6.png" alt="パターン6">
# <img src="./RSSI取得実験図/pattern6-1.JPG" alt="パターン6-1">
# <img src="./RSSI取得実験図/pattern6-2.JPG" alt="パターン6-2">
#
# ### データ整形

# %%
# pattern6の各実験データをそれぞれ取得
P6_1 = pd.read_csv("./取得データセット/受信機1/nkmr1_pattern6.csv")
P6_2 = pd.read_csv("./取得データセット/受信機2/nkmr2_pattern6.csv")
P6_3 = pd.read_csv("./取得データセット/受信機3/nkmr3_pattern6.csv")

# それぞれカラム名を指定
P6_1.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
P6_2.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
P6_3.columns =  ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]

# 結合
df6 = P6_1.append(P6_2).append(P6_3)

# %% [markdown]
# ### 1.受信した全データを見る

# %%
# 受信した全てのデータの分布を見る
sns.distplot(df6["RSSI"])

# データ数、平均値、分散を出力
print("データ数:%s" % df6["RSSI"].count())
print("平均値:%s" % df6["RSSI"].mean())
print("分散:%s" % df6["RSSI"].std())
# Out:
# データ数:45076
# 平均値:-85.27356020942409
# 分散:3.9362353218935286

# %% [markdown]
# ### 2.受信機ごとのRSSI値の変化を見る

# %% [markdown]
# #### 2-1.受信機1の分布

# %%
# 受信機1の全データ分布
sns.distplot(P6_1["RSSI"])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_1["RSSI"].count())
print("平均値:%s" % P6_1["RSSI"].mean())
print("分散:%s" % P6_1["RSSI"].std())
# Out:
# データ数:14337
# 平均値:-84.31198995605776
# 分散:5.22171288945476

# %%
# 発信機1の分布
sns.distplot(P6_1[P6_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_1[P6_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_1[P6_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_1[P6_1["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:5763
# 平均値:-79.65937879576609
# 分散:4.417282500436834

# %%
# 発信機2の分布
sns.distplot(P6_1[P6_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_1[P6_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_1[P6_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_1[P6_1["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2786
# 平均値:-89.27638190954774
# 分散:2.941999828500499

# %%
# 発信機3の分布
sns.distplot(P6_1[P6_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_1[P6_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_1[P6_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_1[P6_1["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:1837
# 平均値:-85.35274904735982
# 分散:1.861696613194832

# %%
# 発信機4の分布
sns.distplot(P6_1[P6_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_1[P6_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_1[P6_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_1[P6_1["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:3951
# 平均値:-87.1138952164009
# 分散:2.336867271847721

# %% [markdown]
# #### 考察(受信機1のRSSI値の分布)
# 平均:①-79.65937879576609、②-89.27638190954774、③-85.35274904735982、④-87.1138952164009
# 分散:①4.417282500436834、②2.941999828500499、③1.861696613194832、④2.336867271847721
#
# 平均値 :
# ①地点はビーコンとの距離が近いためRSSI値が大きい値を示している。
# ②地点では平均値が極端に低い値を示しているが図からグラフの山が２つ出来ていることから反射波による影響が考えられる。
# ③>④地点ではグラフからは反射波の影響をあまり受けていないことが見て取れる。また、平均値は遠ければ遠いほど低い値を示している。
#
# 分散値 :
# 反射波による影響を取りやすい地点では分散の値が高い値を示している。
#
#
# <img src="./RSSI取得実験図/pattern6.png" alt="パターン6">

# %% [markdown]
# #### 2-2.受信機2の分布

# %%
# 発信機1の分布
sns.distplot(P6_2[P6_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_2[P6_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_2[P6_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_2[P6_2["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:1555
# 平均値:-86.24887459807074
# 分散:0.9162783302428862

# %%
 P6_2[P6_2["UUIDs"] == "10000000aaaa41441111110000000000"].groupby("RSSI").count()
# Out:
#       UUIDs  Major  Minor  Accuracy  Proximity  TxPower  device_name  \
# RSSI
# -94       1      1      1         1          1        1            1
# -93       3      3      3         3          3        3            3
# -92       5      5      5         5          5        5            5
# -91      10     10     10        10         10       10           10
# -90      15     15     15        15         15       15           15
# -89      10     10     10        10         10       10           10
# -88      11     11     11        11         11       11           11
# -87     264    264    264       264        264      264          264
# -86    1149   1149   1149      1149       1149     1149         1149
# -85      77     77     77        77         77       77           77
# -84       9      9      9         9          9        9            9
# -83       1      1      1         1          1        1            1
#
#       timestamp
# RSSI
# -94           1
# -93           3
# ...

# %%
# 発信機2の分布
sns.distplot(P6_2[P6_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_2[P6_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_2[P6_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_2[P6_2["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:4302
# 平均値:-85.37517433751744
# 分散:3.4789187622451085

# %%
# 発信機3の分布
sns.distplot(P6_2[P6_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_2[P6_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_2[P6_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_2[P6_2["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:3437
# 平均値:-83.80069828338668
# 分散:1.355418385604531

# %%
# 発信機4の分布
sns.distplot(P6_2[P6_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_2[P6_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_2[P6_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_2[P6_2["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:5257
# 平均値:-85.4124025109378
# 分散:1.6570447918555575

# %% [markdown]
# #### 考察(受信機2のRSSI値の分布)
# 平均:①-86.24887459807074、②-85.37517433751744、③-83.80069828338668、④-85.4124025109378
# 分散:①0.9162783302428862、②3.4789187622451085、③1.355418385604531、④1.6570447918555575
#
# 平均値 :
# 平均値は他のパターンと比較すると全ての地点によって平均的に近い値を示している。
#
# グラフの波形としては予想として(①、④)、(②、③)が等しいと予想したがそのようにはなっていない。
#
#
# <img src="./RSSI取得実験図/pattern6.png" alt="パターン6">

# %% [markdown]
# #### 2-3.受信機3の分布

# %%
# 発信機1の分布
sns.distplot(P6_3[P6_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_3[P6_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_3[P6_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_3[P6_3["UUIDs"] == "10000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2729
# 平均値:-87.05716379626237
# 分散:3.9319300872554237

# %%
# 発信機2の分布
sns.distplot(P6_3[P6_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_3[P6_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_3[P6_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_3[P6_3["UUIDs"] == "20000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:2910
# 平均値:-90.66563573883161
# 分散:1.494997223339954

# %%
# 発信機3の分布
sns.distplot(P6_3[P6_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_3[P6_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_3[P6_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_3[P6_3["UUIDs"] == "30000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:5196
# 平均値:-86.80369515011547
# 分散:2.1800464032075695

# %%
# 発信機4の分布
sns.distplot(P6_3[P6_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6])

# データ数、平均値、分散を出力
print("データ数:%s" % P6_3[P6_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].count())
print("平均値:%s" % P6_3[P6_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].mean())
print("分散:%s" % P6_3[P6_3["UUIDs"] == "40000000aaaa41441111110000000000"].iloc[:,6].std())
# Out:
# データ数:5353
# 平均値:-82.96749486269381
# 分散:0.8395519956847809

# %% [markdown]
# #### 考察(受信機3のRSSI値の分布)
# 平均:①-87.05716379626237、②-90.66563573883161、③-86.80369515011547、④-82.96749486269381
# 分散:①3.9319300872554237、②1.494997223339954、③2.1800464032075695、④0.8395519956847809
#
#
# <img src="./RSSI取得実験図/pattern6.png" alt="パターン6">
