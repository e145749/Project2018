# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import matplotlib as plt
import matplotlib.pyplot as plt
import sklearn.preprocessing as sp
# %matplotlib inline
sns.set_style('whitegrid')
sns.set_context("poster")
sns.set_context("talk", 1.0, {"lines.linewidth": 3})

# %%
# パターン7の各実験データを取得
df7_1 = pd.read_csv("./取得データセット/受信機1/nkmr1_pattern7.csv")
df7_2 = pd.read_csv("./取得データセット/受信機2/nkmr2_pattern7.csv")
df7_3 = pd.read_csv("./取得データセット/受信機3/nkmr3_pattern7.csv")
df7_4 = pd.read_csv("./取得データセット/受信機4/nkmr4_pattern7.csv")


#それぞれのカラム名の指定
df7_1.columns = ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
df7_2.columns = ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
df7_3.columns = ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
df7_4.columns = ["UUIDs","Major","Minor","Accuracy","Proximity","TxPower","RSSI","device_name","timestamp"]
df7_1 = df7_1[df7_1["UUIDs"] != "80000000aaaa41441111110000000000"]
df7_2 = df7_2[df7_2["UUIDs"] != "80000000aaaa41441111110000000000"]
df7_3 = df7_3[df7_3["UUIDs"] != "80000000aaaa41441111110000000000"]
df7_4 = df7_4[df7_4["UUIDs"] != "80000000aaaa41441111110000000000"]

#エラーが出るため、受信機4を処理
df7_4["RSSI"]= df7_4["RSSI"].replace("\\N","")
#df7_4["RSSI"]= df7_4["RSSI"].replace('\r','')
#df7_4["RSSI"]=df7_4["RSSI"].astype(float)
df7_4=df7_4.drop(60637)
df7_4["RSSI"]
df7_4["RSSI"] = df7_4["RSSI"].astype(int)

#データの結合
df7 = df7_1.append(df7_2).append(df7_3).append(df7_4)

#時間を数値に変換
le = sp.LabelEncoder()
le.fit(df7_1[df7_1.columns[8]].unique())
df7_1["date"] = le.transform(df7_1[df7_1.columns[8]])
le.fit(df7_2[df7_1.columns[8]].unique())
df7_2["date"] = le.transform(df7_2[df7_2.columns[8]])
le.fit(df7_3[df7_3.columns[8]].unique())
df7_3["date"] = le.transform(df7_3[df7_3.columns[8]])
le.fit(df7_4[df7_4.columns[8]].unique())
df7_4["date"] = le.transform(df7_4[df7_4.columns[8]])

# 発信機ごとに種類分け
#受信機1
df7_1_1 = df7_1[df7_1['UUIDs']  == "10000000aaaa41441111110000000000"]
df7_1_2 = df7_1[df7_1['UUIDs']  == "20000000aaaa41441111110000000000"]
df7_1_3 = df7_1[df7_1['UUIDs']  == "30000000aaaa41441111110000000000"]
df7_1_4 = df7_1[df7_1['UUIDs']  == "40000000aaaa41441111110000000000"]
df7_1_5 = df7_1[df7_1['UUIDs']  == "50000000aaaa41441111110000000000"]
df7_1_6 = df7_1[df7_1['UUIDs']  == "60000000aaaa41441111110000000000"]
df7_1_7 = df7_1[df7_1['UUIDs']  == "70000000aaaa41441111110000000000"]

#受信機2
df7_2_1 = df7_2[df7_2['UUIDs']  == "10000000aaaa41441111110000000000"]
df7_2_2 = df7_2[df7_2['UUIDs']  == "20000000aaaa41441111110000000000"]
df7_2_3 = df7_2[df7_2['UUIDs']  == "30000000aaaa41441111110000000000"]
df7_2_4 = df7_2[df7_2['UUIDs']  == "40000000aaaa41441111110000000000"]
df7_2_5 = df7_2[df7_2['UUIDs']  == "50000000aaaa41441111110000000000"]
df7_2_6 = df7_2[df7_2['UUIDs']  == "60000000aaaa41441111110000000000"]
df7_2_7 = df7_2[df7_2['UUIDs']  == "70000000aaaa41441111110000000000"]

#受信機3
df7_3_1 = df7_3[df7_3['UUIDs']  == "10000000aaaa41441111110000000000"]
df7_3_2 = df7_3[df7_3['UUIDs']  == "20000000aaaa41441111110000000000"]
df7_3_3 = df7_3[df7_3['UUIDs']  == "30000000aaaa41441111110000000000"]
df7_3_4 = df7_3[df7_3['UUIDs']  == "40000000aaaa41441111110000000000"]
df7_3_5 = df7_3[df7_3['UUIDs']  == "50000000aaaa41441111110000000000"]
df7_3_6 = df7_3[df7_3['UUIDs']  == "60000000aaaa41441111110000000000"]
df7_3_7 = df7_3[df7_3['UUIDs']  == "70000000aaaa41441111110000000000"]

#受信機4
df7_4_1 = df7_4[df7_4['UUIDs']  == "10000000aaaa41441111110000000000"]
df7_4_2 = df7_4[df7_4['UUIDs']  == "20000000aaaa41441111110000000000"]
df7_4_3 = df7_4[df7_4['UUIDs']  == "30000000aaaa41441111110000000000"]
df7_4_4 = df7_4[df7_4['UUIDs']  == "40000000aaaa41441111110000000000"]
df7_4_5 = df7_4[df7_4['UUIDs']  == "50000000aaaa41441111110000000000"]
df7_4_6 = df7_4[df7_4['UUIDs']  == "60000000aaaa41441111110000000000"]
df7_4_7 = df7_4[df7_4['UUIDs']  == "70000000aaaa41441111110000000000"]

# %%
df7_4
# Out:
#                                   UUIDs Major Minor    Accuracy Proximity  \
# 0      70000000aaaa41441111110000000000     2    36  1.10028950      near
# 1      50000000aaaa41441111110000000000     2    32  1.21063699      near
# 3      50000000aaaa41441111110000000000     2    32  1.15414521      near
# 4      70000000aaaa41441111110000000000     2    36           1      near
# 5      50000000aaaa41441111110000000000     2    32           1      near
# 6      70000000aaaa41441111110000000000     2    36  1.10028950      near
# 8      40000000aaaa41441111110000000000     2    35  1.77436035      near
# 9      30000000aaaa41441111110000000000     2    34  1.86120971      near
# 10     70000000aaaa41441111110000000000     2    36           1      near
# 11     60000000aaaa41441111110000000000     2    39  1.46564193      near
# 12     50000000aaaa41441111110000000000     2    32  1.04894685      near
# 13     70000000aaaa41441111110000000000     2    36           1      near
# ...

# %% [markdown]
# ### pattern7のデータを分析
# pattern7では受信機の向きを考慮した基礎実験を行なっている。
# ４隅に置いた発信機に対してBLE受信機のドングルの向きを変えてRSSI値の変化をみる。
# <img src="./RSSI取得実験図/実験7/パターン7.png" alt="パターン7">
# <img src="./RSSI取得実験図/実験7/IMG_2975.JPG" alt="パターン7-1">
# <img src="./RSSI取得実験図/実験7/IMG_9954.JPG" alt="パターン7-2">

# %% [markdown]
# ### 1.全受信機の分布

# %%
# 受信した全てのデータの分布を見る
sns.distplot(df7["RSSI"],bins=30,kde=False)
plt.xlim([-100,-60])
#plt.ylim([0,0.2])

# データ数、平均値、分散を出力
print("データ数:%s" % df7["RSSI"].count())
print("平均値:%s" % df7["RSSI"].mean())
print("分散:%s" % df7["RSSI"].std())
# Out:
# データ数:196807
# 平均値:-85.3963426097649
# 分散:4.438757191671232

# %% [markdown]
# 受信機1つ、ビーコン4つで20分計測した場合、データ数は2万だった。今回は、受信機4つ、ビーコン8つで30分計測し、データ数は19万ほどである。
# 平均値は受信機1つの時が-86.5だったため、今回はそれより少し高めである。おそらく、反射波などによる影響が少ないからと思われる。
# 分散は受信するビーコンの数が多いため、値が1以上多かった。

# %% [markdown]
# ### 2.受信機ごとの分布

# %%
#結合したRSSIの詳細
print("全データのRSSI")
print("データ数:%s" % df7["RSSI"].count())
print("平均値:%s" % df7["RSSI"].mean())
print("分散:%s\n" % df7["RSSI"].std())
print("受信機1")
print("データ数:%s" % df7_1["RSSI"].count())
print("平均値:%s" % df7_1["RSSI"].mean())
print("分散:%s\n" % df7_1["RSSI"].std())
print("受信機2")
print("データ数:%s" % df7_2["RSSI"].count())
print("平均値:%s" % df7_2["RSSI"].mean())
print("分散:%s\n" % df7_2["RSSI"].std())
print("受信機3")
print("データ数:%s" % df7_3["RSSI"].count())
print("平均値:%s" % df7_3["RSSI"].mean())
print("分散:%s\n" % df7_3["RSSI"].std())
print("受信機4")
print("データ数:%s" % df7_4["RSSI"].count())
print("平均値:%s" % df7_4["RSSI"].mean())
print("分散:%s\n" % df7_4["RSSI"].std())
# Out:
# 全データのRSSI
# データ数:196807
# 平均値:-85.3963426097649
# 分散:4.438757191671232
#
# 受信機1
# データ数:45682
# 平均値:-86.6177706755396
# 分散:3.5506107085789527
#
# 受信機2
# データ数:48184
# 平均値:-85.90772870662461
# 分散:4.323830486111887
#
# 受信機3
# データ数:52276
# 平均値:-85.09323590175224
# 分散:5.17603196477114
#
# 受信機4
# データ数:50665
# 平均値:-84.12144478436791
# 分散:4.053525674034393

# %% [markdown]
# データ数は受信機1,2が少し少なく、受信機3,4が少し多い。
# 平均値は受信機1が小さく、4が大きいがあまり差はない。
# 分散は受信機1が小さく、受信機3が大きい。

# %%
print("受信機1\n")

print("point1")
print("データ数:%s" % df7_1_1["RSSI"].count())
print("平均値:%s" % df7_1_1["RSSI"].mean())
print("分散:%s\n" % df7_1_1["RSSI"].std())
print("point2")
print("データ数:%s" % df7_1_2["RSSI"].count())
print("平均値:%s" % df7_1_2["RSSI"].mean())
print("分散:%s\n" % df7_1_2["RSSI"].std())
print("point3")
print("データ数:%s" % df7_1_3["RSSI"].count())
print("平均値:%s" % df7_1_3["RSSI"].mean())
print("分散:%s\n" % df7_1_3["RSSI"].std())
print("point4")
print("データ数:%s" % df7_1_4["RSSI"].count())
print("平均値:%s" % df7_1_4["RSSI"].mean())
print("分散:%s\n" % df7_1_4["RSSI"].std())
print("point5")
print("データ数:%s" % df7_1_5["RSSI"].count())
print("平均値:%s" % df7_1_5["RSSI"].mean())
print("分散:%s\n" % df7_1_5["RSSI"].std())
print("point6")
print("データ数:%s" % df7_1_6["RSSI"].count())
print("平均値:%s" % df7_1_6["RSSI"].mean())
print("分散:%s\n" % df7_1_6["RSSI"].std())
print("point7")
print("データ数:%s" % df7_1_7["RSSI"].count())
print("平均値:%s" % df7_1_7["RSSI"].mean())
print("分散:%s\n" % df7_1_7["RSSI"].std())

print("受信機2\n")

print("point1")
print("データ数:%s" % df7_2_1["RSSI"].count())
print("平均値:%s" % df7_2_1["RSSI"].mean())
print("分散:%s\n" % df7_2_1["RSSI"].std())
print("point2")
print("データ数:%s" % df7_2_2["RSSI"].count())
print("平均値:%s" % df7_2_2["RSSI"].mean())
print("分散:%s\n" % df7_2_2["RSSI"].std())
print("point3")
print("データ数:%s" % df7_2_3["RSSI"].count())
print("平均値:%s" % df7_2_3["RSSI"].mean())
print("分散:%s\n" % df7_2_3["RSSI"].std())
print("point4")
print("データ数:%s" % df7_2_4["RSSI"].count())
print("平均値:%s" % df7_2_4["RSSI"].mean())
print("分散:%s\n" % df7_2_4["RSSI"].std())
print("point5")
print("データ数:%s" % df7_2_5["RSSI"].count())
print("平均値:%s" % df7_2_5["RSSI"].mean())
print("分散:%s\n" % df7_2_5["RSSI"].std())
print("point6")
print("データ数:%s" % df7_2_6["RSSI"].count())
print("平均値:%s" % df7_2_6["RSSI"].mean())
print("分散:%s\n" % df7_2_6["RSSI"].std())
print("point7")
print("データ数:%s" % df7_2_7["RSSI"].count())
print("平均値:%s" % df7_2_7["RSSI"].mean())
print("分散:%s\n" % df7_2_7["RSSI"].std())

print("受信機3\n")

print("point1")
print("データ数:%s" % df7_3_1["RSSI"].count())
print("平均値:%s" % df7_3_1["RSSI"].mean())
print("分散:%s\n" % df7_3_1["RSSI"].std())
print("point2")
print("データ数:%s" % df7_3_2["RSSI"].count())
print("平均値:%s" % df7_3_2["RSSI"].mean())
print("分散:%s\n" % df7_3_2["RSSI"].std())
print("point3")
print("データ数:%s" % df7_3_3["RSSI"].count())
print("平均値:%s" % df7_3_3["RSSI"].mean())
print("分散:%s\n" % df7_3_3["RSSI"].std())
print("point4")
print("データ数:%s" % df7_3_4["RSSI"].count())
print("平均値:%s" % df7_3_4["RSSI"].mean())
print("分散:%s\n" % df7_3_4["RSSI"].std())
print("point5")
print("データ数:%s" % df7_3_5["RSSI"].count())
print("平均値:%s" % df7_3_5["RSSI"].mean())
print("分散:%s\n" % df7_3_5["RSSI"].std())
print("point6")
print("データ数:%s" % df7_3_6["RSSI"].count())
print("平均値:%s" % df7_3_6["RSSI"].mean())
print("分散:%s\n" % df7_3_6["RSSI"].std())
print("point7")
print("データ数:%s" % df7_3_7["RSSI"].count())
print("平均値:%s" % df7_3_7["RSSI"].mean())
print("分散:%s\n" % df7_3_7["RSSI"].std())

print("受信機4\n")

print("point1")
print("データ数:%s" % df7_4_1["RSSI"].count())
print("平均値:%s" % df7_4_1["RSSI"].mean())
print("分散:%s\n" % df7_4_1["RSSI"].std())
print("point2")
print("データ数:%s" % df7_4_2["RSSI"].count())
print("平均値:%s" % df7_4_2["RSSI"].mean())
print("分散:%s\n" % df7_4_2["RSSI"].std())
print("point3")
print("データ数:%s" % df7_4_3["RSSI"].count())
print("平均値:%s" % df7_4_3["RSSI"].mean())
print("分散:%s\n" % df7_4_3["RSSI"].std())
print("point4")
print("データ数:%s" % df7_4_4["RSSI"].count())
print("平均値:%s" % df7_4_4["RSSI"].mean())
print("分散:%s\n" % df7_4_4["RSSI"].std())
print("point5")
print("データ数:%s" % df7_4_5["RSSI"].count())
print("平均値:%s" % df7_4_5["RSSI"].mean())
print("分散:%s\n" % df7_4_5["RSSI"].std())
print("point6")
print("データ数:%s" % df7_4_6["RSSI"].count())
print("平均値:%s" % df7_4_6["RSSI"].mean())
print("分散:%s\n" % df7_4_6["RSSI"].std())
print("point7")
print("データ数:%s" % df7_4_7["RSSI"].count())
print("平均値:%s" % df7_4_7["RSSI"].mean())
print("分散:%s\n" % df7_4_7["RSSI"].std())
# Out:
# 受信機1
#
# point1
# データ数:4909
# 平均値:-89.14279894072112
# 分散:3.8094084708561535
#
# point2
# データ数:4414
# 平均値:-84.09447213411872
# 分散:3.926402149093844
#
# point3
# データ数:10279
# 平均値:-83.61572137367448
# 分散:3.0115574777707868
#
# point4
# データ数:6932
# 平均値:-85.9131563762262
# 分散:1.6575061158539037
#
# point5
# データ数:5371
# 平均値:-88.60733569167753
# 分散:3.5036791243857484
#
# point6
# データ数:7067
# 平均値:-88.49908023206453
# 分散:2.107120811035531
#
# point7
# データ数:6710
# 平均値:-88.18315946348733
# 分散:1.150987510411904
#
# 受信機2
#
# point1
# データ数:3365
# 平均値:-84.26448736998515
# 分散:1.6953288135878046
#
# point2
# データ数:11159
# 平均値:-84.94488753472534
# 分散:2.2446108776180074
#
# point3
# データ数:1107
# 平均値:-93.94579945799458
# 分散:0.8227923871600926
#
# point4
# データ数:4009
# 平均値:-89.17410825642305
# 分散:0.7204720323201234
#
# point5
# データ数:10163
# 平均値:-81.72252287710322
# 分散:6.461759147827791
#
# point6
# データ数:10033
# 平均値:-87.6380942888468
# 分散:1.0869734129402597
#
# point7
# データ数:8348
# 平均値:-88.23814087206516
# ...

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,figsize=(20,7), sharex=True,  sharey=True)
fig, (ax3, ax4) = plt.subplots(ncols=2,figsize=(20,7), sharex=True,  sharey=True)
ax1.set_xlim([-100,-70])
ax1.set_ylim([0,0.4])
ax3.set_xlim([-100,-70])
ax3.set_ylim([0,0.4])
ax1.set_title("nk1")
ax2.set_title("nk2")
ax3.set_title("nk3")
ax4.set_title("nk4")
sns.distplot(df7_1["RSSI"],bins=30,ax=ax1)
sns.distplot(df7_2["RSSI"],bins=30,ax=ax2)
sns.distplot(df7_3["RSSI"],bins=30,ax=ax3)
sns.distplot(df7_4["RSSI"],bins=30,ax=ax4)

# %% [markdown]
# 全ての受信機が同じ数、同じ距離の発信機を受信しているのに分布は違います。平均値はあまり差がありませんでしたが、やはり設置場所によって受信する電波に差があることがわかります。

# %% [markdown]
# ### 3.発信機ごとの分布

# %% [markdown]
# 地点1が赤、地点2が青、地点3が緑、地点4が黄色、地点5が紫、地点6が茶、地点7がピンク

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,figsize=(20,7), sharex=True,  sharey=True)
fig, (ax3, ax4) = plt.subplots(ncols=2,figsize=(20,7), sharex=True,  sharey=True)
ax1.set_xlim([-100,-70])
ax1.set_ylim([0,1.6])
ax3.set_xlim([-100,-70])
ax3.set_ylim([0,1.6])
ax1.set_title("nk1")
ax2.set_title("nk2")
ax3.set_title("nk3")
ax4.set_title("nk4")

sns.distplot(df7_1_1["RSSI"],hist=False,color="red",kde_kws={"label": "point1"},ax=ax1)
sns.distplot(df7_1_2["RSSI"],hist=False,color="blue",kde_kws={"label": "point2"},ax=ax1)
sns.distplot(df7_1_3["RSSI"],hist=False,color="green",kde_kws={"label": "point3"},ax=ax1)
sns.distplot(df7_1_4["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4"},ax=ax1)
sns.distplot(df7_1_5["RSSI"],hist=False,color="black",kde_kws={"label": "point5"},ax=ax1)
sns.distplot(df7_1_6["RSSI"],hist=False,color="brown",kde_kws={"label": "point6"},ax=ax1)
sns.distplot(df7_1_7["RSSI"],hist=False,color="pink",kde_kws={"label": "point7"},ax=ax1)

sns.distplot(df7_2_1["RSSI"],hist=False,color="red",kde_kws={"label": "point1"},ax=ax2)
sns.distplot(df7_2_2["RSSI"],hist=False,color="blue",kde_kws={"label": "point2"},ax=ax2)
sns.distplot(df7_2_3["RSSI"],hist=False,color="green",kde_kws={"label": "point3"},ax=ax2)
sns.distplot(df7_2_4["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4"},ax=ax2)
sns.distplot(df7_2_5["RSSI"],hist=False,color="black",kde_kws={"label": "point5"},ax=ax2)
sns.distplot(df7_2_6["RSSI"],hist=False,color="brown",kde_kws={"label": "point6"},ax=ax2)
sns.distplot(df7_2_7["RSSI"],hist=False,color="pink",kde_kws={"label": "point7"},ax=ax2)

sns.distplot(df7_3_1["RSSI"],hist=False,color="red",kde_kws={"label": "point1"},ax=ax3)
sns.distplot(df7_3_2["RSSI"],hist=False,color="blue",kde_kws={"label": "point2"},ax=ax3)
sns.distplot(df7_3_3["RSSI"],hist=False,color="green",kde_kws={"label": "point3"},ax=ax3)
sns.distplot(df7_3_4["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4"},ax=ax3)
sns.distplot(df7_3_5["RSSI"],hist=False,color="black",kde_kws={"label": "point5"},ax=ax3)
sns.distplot(df7_3_6["RSSI"],hist=False,color="brown",kde_kws={"label": "point6"},ax=ax3)
sns.distplot(df7_3_7["RSSI"],hist=False,color="pink",kde_kws={"label": "point7"},ax=ax3)

sns.distplot(df7_4_1["RSSI"],hist=False,color="red",kde_kws={"label": "point1"},ax=ax4)
sns.distplot(df7_4_2["RSSI"],hist=False,color="blue",kde_kws={"label": "point2"},ax=ax4)
sns.distplot(df7_4_3["RSSI"],hist=False,color="green",kde_kws={"label": "point3"},ax=ax4)
sns.distplot(df7_4_4["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4"},ax=ax4)
sns.distplot(df7_4_5["RSSI"],hist=False,color="black",kde_kws={"label": "point5"},ax=ax4)
sns.distplot(df7_4_6["RSSI"],hist=False,color="brown",kde_kws={"label": "point6"},ax=ax4)
sns.distplot(df7_4_7["RSSI"],hist=False,color="pink",kde_kws={"label": "point7"},ax=ax4)
#sns.plt.savefig('example1.png')
sns.plt.savefig('example0.png',ax=ax1)
print("受信機1")
print("データ数:%s" % df7_1_4["RSSI"].count())
print("平均値:%s" % df7_1_4["RSSI"].mean())
print("分散:%s\n" % df7_1_4["RSSI"].std())
print("受信機2")
print("データ数:%s" % df7_2_4["RSSI"].count())
print("平均値:%s" % df7_2_4["RSSI"].mean())
print("分散:%s\n" % df7_2_4["RSSI"].std())
print("受信機3")
print("データ数:%s" % df7_3_4["RSSI"].count())
print("平均値:%s" % df7_3_4["RSSI"].mean())
print("分散:%s\n" % df7_3_4["RSSI"].std())
print("受信機4")
print("データ数:%s" % df7_4_4["RSSI"].count())
print("平均値:%s" % df7_4_4["RSSI"].mean())
print("分散:%s\n" % df7_4_4["RSSI"].std())
# Out:
# /Users/tomanan/anaconda/envs/py34/lib/python3.4/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# 受信機1
# データ数:6932
# 平均値:-85.9131563762262
# 分散:1.6575061158539037
#
# 受信機2
# データ数:4009
# 平均値:-89.17410825642305
# 分散:0.7204720323201234
#
# 受信機3
# データ数:10776
# 平均値:-87.0329435783222
# 分散:2.7669461841623857
#
# 受信機4
# データ数:6211
# 平均値:-86.74851070681049
# 分散:3.3641850930686004

# %% [markdown]
# どの受信機も分布はバラバラである。
# ビーコン4はどの受信機からも距離が同じであるが、平均値は受信機毎に違う。
# 平均値付近に値が集積しているビーコンも何か法則のようなものがある感じではなかったが、比較的遠い方が値が安定しているような気がする。

# %%
plt.xlim([-100,-70])
plt.ylim([0,1.6])
sns.distplot(df7_3_1["RSSI"],hist=False,color="red",kde_kws={"label": "point1"})
sns.distplot(df7_3_2["RSSI"],hist=False,color="blue",kde_kws={"label": "point2"})
sns.distplot(df7_3_3["RSSI"],hist=False,color="green",kde_kws={"label": "point3"})
sns.distplot(df7_3_4["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4"})
sns.distplot(df7_3_5["RSSI"],hist=False,color="black",kde_kws={"label": "point5"})
sns.distplot(df7_3_6["RSSI"],hist=False,color="brown",kde_kws={"label": "point6"})
sns.distplot(df7_3_7["RSSI"],hist=False,color="pink",kde_kws={"label": "point7"})
sns.plt.savefig('df7_nk3.png')

# %% [markdown]
# ### 4.発信機の時間毎のRSSI分布

# %%
#df7_1s = df7_1[df7_1['date'] == 0]
#df7_1s = df7_1['date'].unique()
#df7_1s = df7_1.loc['0':'1']
#df7_1s = df7_1.drop_duplicates(['date'])
#df7_1s

# %%
#plt.xlim([0,60])
#plt.ylim([-100,-80])
fig, (ax1, ax2) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
fig, (ax3, ax4) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
fig, (ax5, ax6) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
fig, (ax7) = plt.subplots(ncols=1,figsize=(7.5,6), sharex=True,  sharey=True)
ax1.set_title("point1")
ax2.set_title("point2")
ax3.set_title("point3")
ax4.set_title("point4")
ax5.set_title("point5")
ax6.set_title("point6")
ax7.set_title("point7")

ax1.plot(df7_1_1["date"],df7_1_1["RSSI"])
ax1.set_xlim([0,60])
ax1.set_ylim([-100,-70])
ax1.grid(True)
ax2.plot(df7_1_2["date"],df7_1_2["RSSI"])
ax2.grid(True)
ax3.plot(df7_1_3["date"],df7_1_3["RSSI"])
ax3.set_xlim([0,60])
ax3.set_ylim([-100,-70])
ax3.grid(True)
ax4.plot(df7_1_4["date"],df7_1_4["RSSI"])
ax4.grid(True)
ax5.plot(df7_1_5["date"],df7_1_5["RSSI"])
ax5.set_xlim([0,60])
ax5.set_ylim([-100,-70])
ax5.grid(True)
ax6.plot(df7_1_6["date"],df7_1_6["RSSI"])
ax6.grid(True)
ax7.plot(df7_1_7["date"],df7_1_7["RSSI"])
ax7.set_xlim([0,60])
ax7.set_ylim([-100,-70])
# Out:
# (-100, -70)

# %% [markdown]
# 値が一定ということはなく、常に最大値から最小値までを行ったり来たりしている。しかし、この最大値から最小値までの幅が発信機ごとに異なり、point1,3,6が7~8、
# point2,5が10~15、
# point4,7が5ほどととなっている。
# これらの中でも、2と5は特徴的で、2は値が最大値の時は一定になる時があり、最小値はあまり安定していない。5は最初の30秒ほどは2と同じような感じだったが、30秒以降は安定していない。

# %%
print("ビーコン1")
print("データ数:%s" % df7_1_1["RSSI"].count())
print("平均値:%s" % df7_1_1["RSSI"].mean())
print("分散:%s\n" % df7_1_1["RSSI"].std())

print("ビーコン2")
print("データ数:%s" % df7_1_2["RSSI"].count())
print("平均値:%s" % df7_1_2["RSSI"].mean())
print("分散:%s\n" % df7_1_2["RSSI"].std())

fig, (ax1, ax2) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
ax1.set_title("point1")
ax2.set_title("point2")
ax1.plot(df7_1_1["date"],df7_1_1["RSSI"],"bo")
#ax1.set_xlim([0,60])
#ax1.set_ylim([-100,-70])
ax1.grid(True)
ax2.plot(df7_1_2["date"],df7_1_2["RSSI"])
ax2.grid(True)
# Out:
# ビーコン1
# データ数:4909
# 平均値:-89.14279894072112
# 分散:3.8094084708561535
#
# ビーコン2
# データ数:4414
# 平均値:-84.09447213411872
# 分散:3.926402149093844

# %%
print("ビーコン1の2")
print("データ数:%s" % df7_1_2["RSSI"].count())
print("平均値:%s" % df7_1_2["RSSI"].mean())
print("分散:%s\n" % df7_1_2["RSSI"].std())

print("ビーコン2の4")
print("データ数:%s" % df7_2_4["RSSI"].count())
print("平均値:%s" % df7_2_4["RSSI"].mean())
print("分散:%s\n" % df7_2_4["RSSI"].std())

print("ビーコン3の1")
print("データ数:%s" % df7_3_1["RSSI"].count())
print("平均値:%s" % df7_3_1["RSSI"].mean())
print("分散:%s\n" % df7_3_1["RSSI"].std())

print("ビーコン4の6")
print("データ数:%s" % df7_4_6["RSSI"].count())
print("平均値:%s" % df7_4_6["RSSI"].mean())
print("分散:%s\n" % df7_4_6["RSSI"].std())

fig, (ax1, ax2) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
fig, (ax3, ax4) = plt.subplots(ncols=2,figsize=(20,6), sharex=True,  sharey=True)
fig, (ax5) = plt.subplots(ncols=1,figsize=(7.5,6), sharex=True,  sharey=True)

ax1.set_title("point1_2")
ax2.set_title("point2_4")
ax1.plot(df7_1_2["date"],df7_1_2["RSSI"])
#ax1.set_xlim([0,60])
ax1.set_ylim([-100,-70])
ax1.grid(True)
ax2.plot(df7_2_4["date"],df7_2_4["RSSI"])
ax2.grid(True)
ax3.set_title("point3_1")
ax4.set_title("point4_6")
ax3.plot(df7_3_1["date"],df7_3_1["RSSI"])
#ax3.set_xlim([0,60])
ax3.set_ylim([-100,-70])
ax3.grid(True)
ax4.plot(df7_4_6["date"],df7_4_6["RSSI"])
ax4.grid(True)
sns.distplot(df7_1_2["RSSI"],hist=False,color="red",kde_kws={"label": "point1_2"},ax=ax5)
sns.distplot(df7_2_4["RSSI"],hist=False,color="blue",kde_kws={"label": "point2_4"},ax=ax5)
sns.distplot(df7_3_1["RSSI"],hist=False,color="green",kde_kws={"label": "point3_1"},ax=ax5)
sns.distplot(df7_4_6["RSSI"],hist=False,color="yellow",kde_kws={"label": "point4_6"},ax=ax5)
# Out:
# ビーコン1の2
# データ数:4414
# 平均値:-84.09447213411872
# 分散:3.926402149093844
#
# ビーコン2の4
# データ数:4009
# 平均値:-89.17410825642305
# 分散:0.7204720323201234
#
# ビーコン3の1
# データ数:4257
# 平均値:-84.65680056377731
# 分散:0.8918998508294016
#
# ビーコン4の6
# データ数:4667
# 平均値:-87.8296550246411
# 分散:0.8324710741412914

# %% [markdown]
# それぞれの受信機で、平均値に値が集積しているようなグラフ(正規分布)になっているビーコンのグラフを出力しました。
