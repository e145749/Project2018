# %%
import numpy as np
from matplotlib import pyplot as plt


def f(x):
    """最小値を求めたい関数"""
    return 6*x**2 + 16*50/x


def main():
    x = np.arange(0, 10)

    y = f(x)
    plt.plot(x, y, label='f(x)')

    plt.legend()
    plt.show()


if __name__ == '__main__':
    main()
# Out:
# /Users/tomanan/anaconda/envs/py34/lib/python3.4/site-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in true_divide
